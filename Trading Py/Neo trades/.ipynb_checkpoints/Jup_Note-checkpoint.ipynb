# %%
#Extensions - potential

#ADF Test for mean reversion - for stocks and indices that trend up, use differences to model the residual
#For Big markets that do mean reversion etc
# 1. sell above MA, buy below MA
# 2. Sell if Day/Week is +ve, Buy if -ve
# 3. Combine both

#High movements - Black Swan moves
# Recent surprise, quick jumps - a glut or a squeeze which may see retracements
# Above, shorter term analysis eg Open/close gap analyses esp with inefficiencies in new datasets....
# Open and Close seem to be nearer, High/Low are wilder. Anything there?

#Arbitrage: Cross-mkts
#Analysis on High/Low differences etc between cross-markets

#New tickers esp small tickers that move wildly
#Adding new tickers at the bottom and others? Like BTC, JPYx etc

# %%
# !pip install hurst
# !pip install arch 
# !pip install lightgbm 
# !pip install scikit-learn 
# !pip install pmdarima
# !pip install shap
# !pip install numpy pandas

# %%
# Import the libraries
import pyautogui
import time
import pandas as pd
import numpy as np
import plotly.graph_objs as go
import os
import itertools

from datetime import date

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)  # or None for no limit
# Out:
# C:\Users\nitis\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
#Name the Forex and Metals tickers
Curr = [
    #Currencies
    "USDCAD", "USDCHF", "USDCNH", "USDCZK", "USDHUF", "USDJPY", "USDMXN", "USDNOK", "USDPLN", "USDSEK",
    "USDSGD", "USDTHB", "USDTRY", "USDZAR", "USDIDR", "USDINR", 
    'USDX.a','EURX',
    "EURUSD", "GBPUSD","NZDUSD"
    
    #Metals
    ,"XAGUSD.a","XAUUSD.a", "XPTUSD.a",
    
    #ETFs
    'AUS200.a','US30.a','US500.a','UK100.a','NAS100.a','EUSTX50.a','SPA35.a','JPN225.a', 'GER40.a','HK50.a',
    'NETH25.a','CN50.a','SCI25.a','SWI20.a','FRA40.a', #'NOR25.a'
    
#     # US Shares tickers
    "AMD.US-24", "BABA.US-24", "GOOG.US-24", "AMZN.US-24", "AAPL.US-24", "BAC.US-24", "CAT.US-24",
#     "CVX.US-24", "C.US-24", "XOM.US-24", "F.US-24", "GM.US-24", "HPQ.US-24", "IBM.US-24", "INTC.US-24",
    "JPM.US-24", "JNJ.US-24", "MCD.US-24", "META.US-24", "MSFT.US-24", "NKE.US-24", "NVDA.US-24",
    "NFLX.US-24", "ORCL.US-24", "PFE.US-24", "PG.US-24", "SLB.US-24", "SNAP.US-24", "TSLA.US-24", "WMT.US-24",
#     "BA.US-24", "KO.US-24", "DIS.US-24", "UNH.US-24", "VZ.US-24", "RTX.US-24", "V.US-24"
    
    #Commodities and Crypto
    # Swap positive for short
    ,"Wheat", 
#     "Cocoa.a", "Cotton.a", "Sugar.a", "Corn.a",
    #Swap negative for short
    "BTCUSD", "SpotBrent"
#     "Coffee.a", "Soybeans.a", "LDSugar.a", "Cattle.a"
    
    # AU Shares tickers - vet these before
#     "A2M.AU"
#     "AGL.AU", "AIA.AU", "AIZ.AU", "ALD.AU", "ALQ.AU", "ALX.AU", "AMC.AU"

]

# Curr = ['USDCHF','USDCNH','USDSGD','GBPUSD','US500.a','UK100.a','GER40.a','CN50.a']

# %%
#To run the modules created
import sys
sys.path.append("..")                 # if needed to find project_pkg
import project_pkg.dld as dld_module  # import module object
from importlib import reload
reload(dld_module)

# call function/class inside the module
dld_module.dld(Curr)
# Curr2 = ['USDJPY', 'EURUSD','US30.a']
# dld_module.dld(Curr2)

import project_pkg.utils as utils

# %%
# Analysis on the datasets
base_path = r"C:\Users\nitis\Documents\Forex\Data\New data"
res1 = {} #Define the dict

from project_pkg.utils import (
    numpy_slope, Run, Filter, df_div, determine_direction_and_momentum, analyse,
    get_hurst, get_MFDFA, calculate_hurst, rolling_hurst
)

#Loop through all currencies, len(daily)
for name in Curr:
    path = fr"{base_path}\{name}.csv"
    df = pd.read_csv(path, sep='\t', engine='python')
    res1[name] = df

# %%
#Creating new dfs for sans-USD
#Gold and Silver
#One-way symbols:
#Others and crosses by inverting. Easy
symbols = ["XAGUSD.a","XAUUSD.a", 
          "EURUSD", "GBPUSD", "AUDUSD", "NZDUSD",
          "USDCAD", "USDCHF", "USDJPY", "USDMXN", "USDSGD"]
res2 = {} #Define the dict
res2 = df_div(symbols)
# print(res2)
# print(res2.keys())
# print(res2['EURCHF'])

# %%
import pandas as pd
import numpy as np
import project_pkg.filters_2 as filt

# Dictionary to hold the final cockpit rows for reporting
dashboard_records = []

fin_res = res1 | res2
for name, df in fin_res.items():
    try:
        # 1. Run the master matrix calculator on the symbol's dataframe
        processed_df = filt.build_confluence_matrix(df)
        
        # 2. Extract the latest available row (today's live state)
        # Drop rows where MAs are still warming up
        valid_rows = processed_df.dropna()
        
        if valid_rows.empty:
            print(f"⚠️ [Skipping {name}]: Insufficient historical data to warm up MAs.")
            continue
            
        latest_live_row = valid_rows.iloc[-1]
        
        # 3. Pull the live count values directly from the processed state
        COUNT_LONG  = latest_live_row["COUNT_LONG"]
        COUNT_SHORT = latest_live_row["COUNT_SHORT"]
        COUNT_HOLD  = latest_live_row["COUNT_HOLD"]
        
        # Logic Routing Engine
        if COUNT_LONG >= 12 and COUNT_SHORT <=3:
            action = "Long"
        elif COUNT_SHORT >= 12 and COUNT_LONG <=3:
            action = "Short"
        else:
            action = "No"  # Safe default fallback for exact statistical ties
            
        # 4. Pack the structural data row into our master database
        dashboard_records.append({
            "Symbol": name,
            "Spot Price": latest_live_row["<CLOSE>"],
            "Count Long": COUNT_LONG,
            "Count Short": COUNT_SHORT,
            "Count Hold": COUNT_HOLD,
            "Engine Action": action,
            "As Of Date": pd.to_datetime(latest_live_row["<DATE>"]).strftime("%Y-%m-%d")
        })
        
        # print(f"✅ Processed {name.ljust(8)} | Date: {pd.to_datetime(latest_live_row['<DATE>']).strftime('%Y-%m-%d')} | Action: {action}")
        
    except Exception as e:
        print(f"❌ [Error processing {name}]: {str(e)}")

# Final results cockpit compilation
if dashboard_records:
    master_dashboard_df = pd.DataFrame(dashboard_records)
    print(f"\n🚀 Execution Complete: Successfully matrix-scored {len(master_dashboard_df)} symbols.")
else:
    print("\n❌ Execution Complete: No symbols were successfully matrix-scored.")
# Out:
# ⚠️ [Skipping USDIDR]: Insufficient historical data to warm up MAs.
# ⚠️ [Skipping USDINR]: Insufficient historical data to warm up MAs.
# ⚠️ [Skipping RTX.US-24]: Insufficient historical data to warm up MAs.
#
# 🚀 Execution Complete: Successfully matrix-scored 77 symbols.

# %%
#Option to analyse manually
import pandas as pd
# path = fr"C:\Users\nitis\Desktop\List_06 Jun.txt"
# master_dashboard_df2 = pd.read_fwf(path) #For txt file load

from datetime import date

master_dashboard_df2 = master_dashboard_df[master_dashboard_df['Engine Action'] != 'No']

# Get today's date
today = date.today()

# Format the date as 'DD Mon' (e.g., '02 Nov')
date_string = today.strftime('%d %b')

filename = f"List_{date_string}.txt"

# Create the text output string
text_output = master_dashboard_df.to_string(index=False, header=True)

# 2. DEFINE THE FULL PATH
import os
base_path = r'C:\Users\nitis\Desktop'
base_path2 = r'C:\Users\nitis\Desktop\Fin stuff\Week output'

full_path = os.path.join(base_path, filename)
full_path2 = os.path.join(base_path2, filename)

# Write the string directly to the file
with open(full_path, 'w', encoding='utf-8') as f:
    f.write(text_output)

# Write the string directly to the file
with open(full_path2, 'w', encoding='utf-8') as f:
    f.write(text_output)

# %%
# %load_ext autoreload
# %autoreload 2

# To run the modules created
from project_pkg.model import (
    calculate_technical_indicators,
    run_walk_forward_validation_tuned, 
    predict_next_day_scenarios
)

import pandas as pd
import warnings

# IMPORT VALUEWARNING SO PYTHON RECOGNIZES IT
from statsmodels.tools.sm_exceptions import ValueWarning

# 1. Force Python to silence the specific statsmodels base warnings
warnings.filterwarnings("ignore", category=ValueWarning, module="statsmodels")
warnings.filterwarnings("ignore", category=FutureWarning, module="statsmodels")

# Quick catch-all backup if the module path names differ slightly in your environment:
warnings.filterwarnings("ignore", message=".*No supported index is available.*")

# 1. Create a manual filtered DataFrame for your specific tech basket
# manual_tickers = [
#     "GOOG.US-24", "AMZN.US-24", "AAPL.US-24", "AMD.US-24", "NVDA.US-24", 
#     "MSFT.US-24", "TSLA.US-24", "META.US-24", "ORCL.US-24", "NAS100.a"
#     'SpotBrent','Wheat','XPTUSD.a'
#     'XAGUSD.a','NAS100.a','XAUUSD.a'
# ]
# master_dashboard_df2 = pd.DataFrame(manual_tickers, columns=['Symbol'])

# 2. Loop through the unique currencies in the filtered DataFrame
for currency in master_dashboard_df2['Symbol']:
    # Ensure we handle any potential missing/NaN values safely
    if pd.isna(currency):
        continue
        
    # Construct the file path using an f-string
    file_path = fr"C:\Users\nitis\Documents\Forex\Data\New data\{currency}.csv"
    
    print(f"\n==================================================")
    print(f"PROCESSING ASSET PIPELINE FOR: {currency}")
    print(f"==================================================")
    
    # Read the CSV file
    df_mod = pd.read_csv(file_path, sep='\t', engine='python')

    # --- RUN THE TUNED REGRESSION BACKTEST ---
    # train_window=300 aligns with your production engine historical training lookback
    (
        historical_mae, 
        historical_sharpe, 
        historical_sortino, 
        historical_max_dd, 
        bench_sharpe,
        ranked_features
    ) = run_walk_forward_validation_tuned(
        df=df_mod, 
        train_window=300,
        retrain_interval=100
    )

    print("\n" + "="*50)
    print("           TUNED HISTORICAL BACKTEST RESULTS      ")
    print("==================================================")
    print(f"Regression Mean Absolute Error (MAE): {historical_mae:.5f}")
    print("==================================================")
    print(f"Strategy Sharpe Ratio: {historical_sharpe:.2f}  (Benchmark B&H: {bench_sharpe:.2f})") 
    print("==================================================")
    print(f"Strategy Sortino Ratio: {historical_sortino:.2f}") 
    print("==================================================")
    print(f"Max Peak-to-Trough Drawdown:   {historical_max_dd:.2%}") 
    print("==================================================")
    print("\n           COMPLETE FEATURE IMPORTANCE RANKINGS     ")
    print("==================================================")
    for rank, (feature, importance) in enumerate(ranked_features, 1):
         print(f"Rank {rank:02d}: {feature:<22} -> Relative Impact: {importance:.2f}%")
    print("==================================================")

    # --- GENERATE INTRADAY DEVELOPMENT SCENARIOS FOR TOMORROW ---
    # This runs the 6-scenario decision rubric and outputs your interactive trade board
    predict_next_day_scenarios(df_mod, train_window=300)
# Out:
# ==================================================
# PROCESSING ASSET PIPELINE FOR: USDJPY
# ==================================================
#
# ==================================================
#            TUNED HISTORICAL BACKTEST RESULTS
# ==================================================
# Regression Mean Absolute Error (MAE): 0.00447
# ==================================================
# Strategy Sharpe Ratio: 0.75  (Benchmark B&H: 0.59)
# ==================================================
# Strategy Sortino Ratio: 1.03
# ==================================================
# Max Peak-to-Trough Drawdown:   -2.14%
# ==================================================
#
#            COMPLETE FEATURE IMPORTANCE RANKINGS
# ==================================================
# Rank 01: price_zscore_50        -> Relative Impact: 13.40%
# Rank 02: volatility_5           -> Relative Impact: 11.72%
# Rank 03: vol_acceleration       -> Relative Impact: 11.30%
# Rank 04: dist_MA_5              -> Relative Impact: 9.82%
# Rank 05: RSI                    -> Relative Impact: 7.30%
# Rank 06: Stochastic_14          -> Relative Impact: 6.98%
# Rank 07: ROC_10                 -> Relative Impact: 6.51%
# Rank 08: dist_MA_20             -> Relative Impact: 6.44%
# Rank 09: NTR_5                  -> Relative Impact: 6.34%
# Rank 10: volume_ratio           -> Relative Impact: 5.85%
# Rank 11: CO_spread              -> Relative Impact: 4.95%
# Rank 12: returns                -> Relative Impact: 4.14%
# Rank 13: HL_spread              -> Relative Impact: 3.27%
# Rank 14: volume_spread_ratio    -> Relative Impact: 1.97%
# ==================================================
#
# ========================================================================================================================================
#                                            WEEKLY MACRO HEALTH CHECK MATRIX
# ========================================================================================================================================
#  [STRUCTURAL TREND]     Close vs 200-Day MA (40-Week Proxy)  : ABOVE (Bullish Structure)
#  [MACRO MOMENTUM]       Close vs 50-Day EMA (10-Week Proxy)  : ABOVE (Macro Momentum Intact)
#  [INSTITUTION VOLUME]   Recent 5-Day Volume Magnitude        : -0.9% Spike vs 20-Day Avg
#  [REGIME VOLATILITY]    5-Day ATR Historical Percentile      : 100.0th Percentile (Historical Scale)
# ========================================================================================================================================
#
# ==================================================================================================================================
#                                    LIVE DAILY DEVELOPMENT SCENARIO MATRIX WITH RISK TARGETS
# ==================================================================================================================================
#  Reference Price Close: 161.36200  │  Current Daily Volatility Context (ATR_5): 0.92760
#  Last Closed Session:   2026.07.03
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#  STRUCTURAL DEVELOPMENT SCENARIO  │ SIM CLOSE  │ MODEL VECTOR │ TACTICAL VECTOR    │ TAKE PROFIT  │ STOP LOSS
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#  1. Pure Positive Breakout        │ 161.91856  │ +0.0424%    │ BUY LONG  +0.17x   │ 163.30996    │ 160.99096
#  2. Positive + Upper Wick Drop    │ 161.45476  │ +0.1196%    │ BUY LONG  +0.48x   │ 162.84616    │ 160.52716
#  3. Pure Negative Breakdown       │ 160.80544  │ +0.0736%    │ BUY LONG  +0.29x   │ 162.19684    │ 159.87784
#  4. Negative + Lower Wick Sweep   │ 161.26924  │ +0.1038%    │ BUY LONG  +0.42x   │ 162.66064    │ 160.34164
#  5. Compressed Neutral Chop       │ 161.36200  │ +0.0858%    │ BUY LONG  +0.35x   │ 162.75340    │ 160.43440
#  6. High-Vol Indecision Cross     │ 161.36200  │ +0.0931%    │ BUY LONG  +0.38x   │ 162.75340    │ 160.43440
# ==================================================================================================================================
#
#                                           DYNAMIC 4-METRIC DATA-DRIVEN REGIME COCKPIT
# ----------------------------------------------------------------------------------------------------------------------------------
#  [METRIC VALUES]  Trend Z: +1.45 (Med: +0.57) | Mom Dist: +0.0075 (Med: +0.0102)
#                   Vol Spike: -0.9% (Med: -0.6%) | ATR Ratio: 1.38 (Med: 0.97)
# ----------------------------------------------------------------------------------------------------------------------------------
#  [STATE: TRANSITIONAL REGIME MIX]
#    -> Profile : Mixed macro signals (conflicting trend/momentum directions or detached volume/volatility parameters).
#    -> Bias    : Standard baseline allocations. Let localized technical indicators sort out micro-edge variations.
# ----------------------------------------------------------------------------------------------------------------------------------
#
# Calculating historical macro-durability metrics for engine audit...
#
# =====================================================================
#              DAILY MODEL REGIME RISK & DURABILITY MATRIX
# =====================================================================
#  REGIME ENVIRONMENT               │ STRAT SHARPE │ SORTINO │ MAX DD  │ BENCH SHARPE
# ──────────────────────────────────┼──────────────┼─────────┼─────────┼─────────────
#  Raw Historical Baseline Data     │     0.75     │   1.03  │  -2.1% │     0.59
#  Flavor 1: Liquidity Black Hole   │     0.93     │   1.50  │  -3.5% │     --
#  Flavor 2: Structural Bear Market │    -0.33     │  -0.38  │ -16.6% │     --
#  Flavor 3: High-Volatility Grind  │     3.16     │   5.10  │  -4.5% │     --
#  Flavor 4: The Gold Rush (Bubble) │    -0.52     │  -0.51  │ -10.5% │     --
# =====================================================================
#
#
# ==================================================
# PROCESSING ASSET PIPELINE FOR: USDNOK
# ==================================================
#
# ==================================================
#            TUNED HISTORICAL BACKTEST RESULTS
# ==================================================
# Regression Mean Absolute Error (MAE): 0.00518
# ==================================================
# Strategy Sharpe Ratio: -0.06  (Benchmark B&H: -0.20)
# ==================================================
# Strategy Sortino Ratio: -0.10
# ==================================================
# Max Peak-to-Trough Drawdown:   -5.69%
# ==================================================
#
#            COMPLETE FEATURE IMPORTANCE RANKINGS
# ==================================================
# Rank 01: NTR_5                  -> Relative Impact: 13.98%
# Rank 02: ROC_10                 -> Relative Impact: 10.10%
# Rank 03: RSI                    -> Relative Impact: 8.25%
# Rank 04: vol_acceleration       -> Relative Impact: 7.93%
# Rank 05: dist_MA_5              -> Relative Impact: 7.54%
# Rank 06: CO_spread              -> Relative Impact: 7.35%
# Rank 07: volatility_5           -> Relative Impact: 6.93%
# Rank 08: returns                -> Relative Impact: 6.46%
# Rank 09: volume_ratio           -> Relative Impact: 6.39%
# Rank 10: volume_spread_ratio    -> Relative Impact: 6.17%
# Rank 11: Stochastic_14          -> Relative Impact: 5.99%
# Rank 12: HL_spread              -> Relative Impact: 4.46%
# Rank 13: dist_MA_20             -> Relative Impact: 4.37%
# Rank 14: price_zscore_50        -> Relative Impact: 4.09%
# ==================================================
#
# ========================================================================================================================================
#                                            WEEKLY MACRO HEALTH CHECK MATRIX
# ========================================================================================================================================
#  [STRUCTURAL TREND]     Close vs 200-Day MA (40-Week Proxy)  : ABOVE (Bullish Structure)
#  [MACRO MOMENTUM]       Close vs 50-Day EMA (10-Week Proxy)  : ABOVE (Macro Momentum Intact)
#  [INSTITUTION VOLUME]   Recent 5-Day Volume Magnitude        : -1.2% Spike vs 20-Day Avg
#  [REGIME VOLATILITY]    5-Day ATR Historical Percentile      : 80.0th Percentile (Historical Scale)
# ========================================================================================================================================
#
# ==================================================================================================================================
#                                    LIVE DAILY DEVELOPMENT SCENARIO MATRIX WITH RISK TARGETS
# ==================================================================================================================================
#  Reference Price Close: 9.82677  │  Current Daily Volatility Context (ATR_5): 0.12344
#  Last Closed Session:   2026.07.03
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#  STRUCTURAL DEVELOPMENT SCENARIO  │ SIM CLOSE  │ MODEL VECTOR │ TACTICAL VECTOR    │ TAKE PROFIT  │ STOP LOSS
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#  1. Pure Positive Breakout        │ 9.90083    │ +0.0240%    │ STANDBY (No Edge)  │   N/A │   N/A
#  2. Positive + Upper Wick Drop    │ 9.83911    │ +0.0508%    │ BUY LONG  +0.08x   │ 10.02427     │ 9.71568
#  3. Pure Negative Breakdown       │ 9.75271    │ +0.0174%    │ STANDBY (No Edge)  │   N/A │   N/A
#  4. Negative + Lower Wick Sweep   │ 9.81443    │ +0.0556%    │ BUY LONG  +0.09x   │ 9.99958      │ 9.69099
#  5. Compressed Neutral Chop       │ 9.82677    │ -0.1773%    │ SELL SHORT -0.29x  │ 9.64161      │ 9.95021
#  6. High-Vol Indecision Cross     │ 9.82677    │ +0.0113%    │ STANDBY (No Edge)  │   N/A │   N/A
# ==================================================================================================================================
#
#                                           DYNAMIC 4-METRIC DATA-DRIVEN REGIME COCKPIT
# ----------------------------------------------------------------------------------------------------------------------------------
#  [METRIC VALUES]  Trend Z: +0.23 (Med: -0.14) | Mom Dist: +0.0329 (Med: -0.0001)
#                   Vol Spike: -1.2% (Med: -0.7%) | ATR Ratio: 1.13 (Med: 0.98)
# ----------------------------------------------------------------------------------------------------------------------------------
#  [STATE: TRANSITIONAL REGIME MIX]
#    -> Profile : Mixed macro signals (conflicting trend/momentum directions or detached volume/volatility parameters).
#    -> Bias    : Standard baseline allocations. Let localized technical indicators sort out micro-edge variations.
# ----------------------------------------------------------------------------------------------------------------------------------
#
# Calculating historical macro-durability metrics for engine audit...
#
# =====================================================================
#              DAILY MODEL REGIME RISK & DURABILITY MATRIX
# =====================================================================
#  REGIME ENVIRONMENT               │ STRAT SHARPE │ SORTINO │ MAX DD  │ BENCH SHARPE
# ──────────────────────────────────┼──────────────┼─────────┼─────────┼─────────────
#  Raw Historical Baseline Data     │    -0.06     │  -0.10  │  -5.7% │    -0.20
#  Flavor 1: Liquidity Black Hole   │    -0.52     │  -0.46  │  -9.2% │     --
#  Flavor 2: Structural Bear Market │     0.52     │   0.67  │  -9.2% │     --
#  Flavor 3: High-Volatility Grind  │     2.76     │   4.29  │  -5.9% │     --
#  Flavor 4: The Gold Rush (Bubble) │     0.43     │   0.90  │  -3.7% │     --
# =====================================================================
#
#
# ==================================================
# PROCESSING ASSET PIPELINE FOR: USDSEK
# ==================================================
#
# ==================================================
#            TUNED HISTORICAL BACKTEST RESULTS
# ==================================================
# Regression Mean Absolute Error (MAE): 0.00506
# ==================================================
# Strategy Sharpe Ratio: -1.00  (Benchmark B&H: -0.18)
# ==================================================
# Strategy Sortino Ratio: -1.17
# ==================================================
# Max Peak-to-Trough Drawdown:   -6.97%
# ==================================================
#
#            COMPLETE FEATURE IMPORTANCE RANKINGS
# ==================================================
# Rank 01: volatility_5           -> Relative Impact: 11.09%
# Rank 02: RSI                    -> Relative Impact: 9.65%
# Rank 03: price_zscore_50        -> Relative Impact: 8.79%
# Rank 04: volume_ratio           -> Relative Impact: 7.96%
# Rank 05: dist_MA_20             -> Relative Impact: 7.61%
# Rank 06: Stochastic_14          -> Relative Impact: 7.03%
# Rank 07: returns                -> Relative Impact: 6.82%
# Rank 08: ROC_10                 -> Relative Impact: 6.40%
# Rank 09: vol_acceleration       -> Relative Impact: 6.39%
# Rank 10: NTR_5                  -> Relative Impact: 6.23%
# Rank 11: dist_MA_5              -> Relative Impact: 5.89%
# Rank 12: CO_spread              -> Relative Impact: 5.77%
# Rank 13: HL_spread              -> Relative Impact: 5.50%
# Rank 14: volume_spread_ratio    -> Relative Impact: 4.86%
# ==================================================
#
# ========================================================================================================================================
#                                            WEEKLY MACRO HEALTH CHECK MATRIX
# ========================================================================================================================================
#  [STRUCTURAL TREND]     Close vs 200-Day MA (40-Week Proxy)  : ABOVE (Bullish Structure)
#  [MACRO MOMENTUM]       Close vs 50-Day EMA (10-Week Proxy)  : ABOVE (Macro Momentum Intact)
#  [INSTITUTION VOLUME]   Recent 5-Day Volume Magnitude        : -3.4% Spike vs 20-Day Avg
#  [REGIME VOLATILITY]    5-Day ATR Historical Percentile      : 20.0th Percentile (Historical Scale)
# ========================================================================================================================================
#
# ==================================================================================================================================
#                                    LIVE DAILY DEVELOPMENT SCENARIO MATRIX WITH RISK TARGETS
# ==================================================================================================================================
#  Reference Price Close: 9.64435  │  Current Daily Volatility Context (ATR_5): 0.09588
#  Last Closed Session:   2026.07.03
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#  STRUCTURAL DEVELOPMENT SCENARIO  │ SIM CLOSE  │ MODEL VECTOR │ TACTICAL VECTOR    │ TAKE PROFIT  │ STOP LOSS
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#  1. Pure Positive Breakout        │ 9.70188    │ -0.1557%    │ SELL SHORT -0.24x  │ 9.55806      │ 9.79775
#  2. Positive + Upper Wick Drop    │ 9.65394    │ -0.1320%    │ SELL SHORT -0.21x  │ 9.51012      │ 9.74982
#  3. Pure Negative Breakdown       │ 9.58682    │ -0.0072%    │ STANDBY (No Edge)  │   N/A │   N/A
#  4. Negative + Lower Wick Sweep   │ 9.63476    │ -0.1225%    │ SELL SHORT -0.19x  │ 9.49095      │ 9.73064
#  5. Compressed Neutral Chop       │ 9.64435    │ -0.1674%    │ SELL SHORT -0.26x  │ 9.50053      │ 9.74023
#  6. High-Vol Indecision Cross     │ 9.64435    │ -0.2370%    │ SELL SHORT -0.37x  │ 9.50053      │ 9.74023
# ==================================================================================================================================
#
#                                           DYNAMIC 4-METRIC DATA-DRIVEN REGIME COCKPIT
# ----------------------------------------------------------------------------------------------------------------------------------
#  [METRIC VALUES]  Trend Z: +1.81 (Med: -0.40) | Mom Dist: +0.0231 (Med: -0.0010)
#                   Vol Spike: -3.4% (Med: -0.9%) | ATR Ratio: 0.96 (Med: 0.98)
# ----------------------------------------------------------------------------------------------------------------------------------
#  [STATE: MATURE INSTITUTIONAL GRIND]
#    -> Profile : Elevated trend and momentum, but trading volume and true range are drying up.
#    -> Bias    : Reduce global position sizes. This is a low-liquidity grinding environment prone to false breakouts.
# ----------------------------------------------------------------------------------------------------------------------------------
#
# Calculating historical macro-durability metrics for engine audit...
#
# =====================================================================
#              DAILY MODEL REGIME RISK & DURABILITY MATRIX
# =====================================================================
#  REGIME ENVIRONMENT               │ STRAT SHARPE │ SORTINO │ MAX DD  │ BENCH SHARPE
# ──────────────────────────────────┼──────────────┼─────────┼─────────┼─────────────
#  Raw Historical Baseline Data     │    -1.00     │  -1.17  │  -7.0% │    -0.18
#  Flavor 1: Liquidity Black Hole   │    -0.03     │  -0.05  │  -5.8% │     --
#  Flavor 2: Structural Bear Market │    -0.29     │  -0.40  │  -8.9% │     --
#  Flavor 3: High-Volatility Grind  │     3.25     │   5.25  │  -4.7% │     --
#  Flavor 4: The Gold Rush (Bubble) │    -0.53     │  -0.53  │  -4.1% │     --
# =====================================================================
#
#
# ==================================================
# PROCESSING ASSET PIPELINE FOR: NZDUSD
# ==================================================
# ==================================================
#            TUNED HISTORICAL BACKTEST RESULTS
# ==================================================
# Regression Mean Absolute Error (MAE): 0.00468
# ==================================================
# Strategy Sharpe Ratio: -0.49  (Benchmark B&H: -0.25)
# ==================================================
# Strategy Sortino Ratio: -0.61
# ==================================================
# Max Peak-to-Trough Drawdown:   -3.35%
# ==================================================
#
#            COMPLETE FEATURE IMPORTANCE RANKINGS
# ==================================================
# Rank 01: Stochastic_14          -> Relative Impact: 12.16%
# Rank 02: NTR_5                  -> Relative Impact: 11.87%
# Rank 03: volume_spread_ratio    -> Relative Impact: 9.73%
# Rank 04: dist_MA_5              -> Relative Impact: 9.42%
# Rank 05: RSI                    -> Relative Impact: 8.13%
# Rank 06: vol_acceleration       -> Relative Impact: 7.51%
# Rank 07: volume_ratio           -> Relative Impact: 6.53%
# Rank 08: ROC_10                 -> Relative Impact: 6.04%
# Rank 09: volatility_5           -> Relative Impact: 6.03%
# Rank 10: HL_spread              -> Relative Impact: 5.50%
# Rank 11: CO_spread              -> Relative Impact: 4.74%
# Rank 12: price_zscore_50        -> Relative Impact: 4.70%
# Rank 13: returns                -> Relative Impact: 3.95%
# Rank 14: dist_MA_20             -> Relative Impact: 3.69%
# ==================================================
#
# ========================================================================================================================================
#                                            WEEKLY MACRO HEALTH CHECK MATRIX
# ========================================================================================================================================
#  [STRUCTURAL TREND]     Close vs 200-Day MA (40-Week Proxy)  : BELOW (Bearish Structure)
#  [MACRO MOMENTUM]       Close vs 50-Day EMA (10-Week Proxy)  : BELOW (Short-Term Macro Fatigue)
#  [INSTITUTION VOLUME]   Recent 5-Day Volume Magnitude        : -11.3% Spike vs 20-Day Avg
#  [REGIME VOLATILITY]    5-Day ATR Historical Percentile      : 40.0th Percentile (Historical Scale)
# ========================================================================================================================================
#
# ==================================================================================================================================
#                                    LIVE DAILY DEVELOPMENT SCENARIO MATRIX WITH RISK TARGETS
# ==================================================================================================================================
#  Reference Price Close: 0.57072  │  Current Daily Volatility Context (ATR_5): 0.00491
#  Last Closed Session:   2026.07.03
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#  STRUCTURAL DEVELOPMENT SCENARIO  │ SIM CLOSE  │ MODEL VECTOR │ TACTICAL VECTOR    │ TAKE PROFIT  │ STOP LOSS
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#  1. Pure Positive Breakout        │ 0.57367    │ -0.1474%    │ SELL SHORT -0.25x  │ 0.56630      │ 0.57858
#  2. Positive + Upper Wick Drop    │ 0.57121    │ +0.1203%    │ BUY LONG  +0.20x   │ 0.57858      │ 0.56630
#  3. Pure Negative Breakdown       │ 0.56777    │ +0.1585%    │ BUY LONG  +0.27x   │ 0.57514      │ 0.56286
#  4. Negative + Lower Wick Sweep   │ 0.57023    │ +0.1126%    │ BUY LONG  +0.19x   │ 0.57760      │ 0.56532
#  5. Compressed Neutral Chop       │ 0.57072    │ +0.2167%    │ BUY LONG  +0.37x   │ 0.57809      │ 0.56581
#  6. High-Vol Indecision Cross     │ 0.57072    │ +0.1023%    │ BUY LONG  +0.17x   │ 0.57809      │ 0.56581
# ==================================================================================================================================
#
#                                           DYNAMIC 4-METRIC DATA-DRIVEN REGIME COCKPIT
# ----------------------------------------------------------------------------------------------------------------------------------
#  [METRIC VALUES]  Trend Z: -1.07 (Med: +0.02) | Mom Dist: -0.0185 (Med: -0.0031)
#                   Vol Spike: -11.3% (Med: -1.5%) | ATR Ratio: 0.96 (Med: 0.99)
# ----------------------------------------------------------------------------------------------------------------------------------
#  [STATE: APATHY SECTOR / EQUILIBRIUM]
#    -> Profile : Below average trend, momentum, volume, and volatility. The asset is entirely dormant.
#    -> Bias    : Maintain minimal standard allocations. Rely on tight-bound parameters until institutional volume returns.
# ----------------------------------------------------------------------------------------------------------------------------------
#
# Calculating historical macro-durability metrics for engine audit...
#
# =====================================================================
#              DAILY MODEL REGIME RISK & DURABILITY MATRIX
# =====================================================================
#  REGIME ENVIRONMENT               │ STRAT SHARPE │ SORTINO │ MAX DD  │ BENCH SHARPE
# ──────────────────────────────────┼──────────────┼─────────┼─────────┼─────────────
#  Raw Historical Baseline Data     │    -0.49     │  -0.61  │  -3.4% │    -0.25
#  Flavor 1: Liquidity Black Hole   │    -0.88     │  -0.73  │ -12.4% │     --
#  Flavor 2: Structural Bear Market │    -0.08     │  -0.09  │  -6.8% │     --
#  Flavor 3: High-Volatility Grind  │     3.13     │   5.18  │  -4.9% │     --
#  Flavor 4: The Gold Rush (Bubble) │    -0.61     │  -0.54  │  -4.8% │     --
# =====================================================================
#
#
# ==================================================
# PROCESSING ASSET PIPELINE FOR: UK100.a
# ==================================================
#
# ==================================================
#            TUNED HISTORICAL BACKTEST RESULTS
# ==================================================
# Regression Mean Absolute Error (MAE): 0.00543
# ==================================================
# Strategy Sharpe Ratio: -0.07  (Benchmark B&H: 0.80)
# ==================================================
# Strategy Sortino Ratio: -0.09
# ==================================================
# Max Peak-to-Trough Drawdown:   -8.98%
# ==================================================
#
#            COMPLETE FEATURE IMPORTANCE RANKINGS
# ==================================================
# Rank 01: RSI                    -> Relative Impact: 17.01%
# Rank 02: dist_MA_5              -> Relative Impact: 11.19%
# Rank 03: ROC_10                 -> Relative Impact: 10.35%
# Rank 04: HL_spread              -> Relative Impact: 8.71%
# Rank 05: volume_ratio           -> Relative Impact: 8.44%
# Rank 06: volume_spread_ratio    -> Relative Impact: 6.83%
# Rank 07: vol_acceleration       -> Relative Impact: 5.64%
# Rank 08: returns                -> Relative Impact: 5.32%
# Rank 09: NTR_5                  -> Relative Impact: 5.24%
# Rank 10: CO_spread              -> Relative Impact: 5.01%
# Rank 11: dist_MA_20             -> Relative Impact: 4.37%
# Rank 12: Stochastic_14          -> Relative Impact: 4.31%
# Rank 13: price_zscore_50        -> Relative Impact: 4.23%
# Rank 14: volatility_5           -> Relative Impact: 3.34%
# ==================================================
#
# ========================================================================================================================================
#                                            WEEKLY MACRO HEALTH CHECK MATRIX
# ========================================================================================================================================
#  [STRUCTURAL TREND]     Close vs 200-Day MA (40-Week Proxy)  : ABOVE (Bullish Structure)
#  [MACRO MOMENTUM]       Close vs 50-Day EMA (10-Week Proxy)  : ABOVE (Macro Momentum Intact)
#  [INSTITUTION VOLUME]   Recent 5-Day Volume Magnitude        : -6.3% Spike vs 20-Day Avg
#  [REGIME VOLATILITY]    5-Day ATR Historical Percentile      : 60.0th Percentile (Historical Scale)
# ========================================================================================================================================
#
# ==================================================================================================================================
#                                    LIVE DAILY DEVELOPMENT SCENARIO MATRIX WITH RISK TARGETS
# ==================================================================================================================================
#  Reference Price Close: 10629.60000  │  Current Daily Volatility Context (ATR_5): 152.66000
#  Last Closed Session:   2026.07.03
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#  STRUCTURAL DEVELOPMENT SCENARIO  │ SIM CLOSE  │ MODEL VECTOR │ TACTICAL VECTOR    │ TAKE PROFIT  │ STOP LOSS
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#  1. Pure Positive Breakout        │ 10721.19600 │ -0.0322%    │ STANDBY (No Edge)  │   N/A │   N/A
#  2. Positive + Upper Wick Drop    │ 10644.86600 │ +0.0163%    │ STANDBY (No Edge)  │   N/A │   N/A
#  3. Pure Negative Breakdown       │ 10538.00400 │ +0.3420%    │ BUY LONG  +0.45x   │ 10766.99400  │ 10385.34400
#  4. Negative + Lower Wick Sweep   │ 10614.33400 │ +0.0449%    │ BUY LONG  +0.06x   │ 10843.32400  │ 10461.67400
#  5. Compressed Neutral Chop       │ 10629.60000 │ +0.0327%    │ STANDBY (No Edge)  │   N/A │   N/A
#  6. High-Vol Indecision Cross     │ 10629.60000 │ +0.0426%    │ BUY LONG  +0.06x   │ 10858.59000  │ 10476.94000
# ==================================================================================================================================
#
#                                           DYNAMIC 4-METRIC DATA-DRIVEN REGIME COCKPIT
# ----------------------------------------------------------------------------------------------------------------------------------
#  [METRIC VALUES]  Trend Z: +1.33 (Med: +1.16) | Mom Dist: +0.0225 (Med: +0.0092)
#                   Vol Spike: -6.3% (Med: -1.1%) | ATR Ratio: 1.10 (Med: 0.99)
# ----------------------------------------------------------------------------------------------------------------------------------
#  [STATE: TRANSITIONAL REGIME MIX]
#    -> Profile : Mixed macro signals (conflicting trend/momentum directions or detached volume/volatility parameters).
#    -> Bias    : Standard baseline allocations. Let localized technical indicators sort out micro-edge variations.
# ----------------------------------------------------------------------------------------------------------------------------------
#
# Calculating historical macro-durability metrics for engine audit...
#
# =====================================================================
#              DAILY MODEL REGIME RISK & DURABILITY MATRIX
# =====================================================================
#  REGIME ENVIRONMENT               │ STRAT SHARPE │ SORTINO │ MAX DD  │ BENCH SHARPE
# ──────────────────────────────────┼──────────────┼─────────┼─────────┼─────────────
#  Raw Historical Baseline Data     │    -0.07     │  -0.09  │  -9.0% │     0.80
#  Flavor 1: Liquidity Black Hole   │     0.03     │   0.04  │ -14.2% │     --
#  Flavor 2: Structural Bear Market │     0.70     │   0.87  │ -12.2% │     --
#  Flavor 3: High-Volatility Grind  │     3.58     │   6.64  │  -4.4% │     --
#  Flavor 4: The Gold Rush (Bubble) │    -1.33     │  -1.04  │ -39.4% │     --
# =====================================================================
#
#
# ==================================================
# PROCESSING ASSET PIPELINE FOR: FRA40.a
# ==================================================
#
# ==================================================
#            TUNED HISTORICAL BACKTEST RESULTS
# ==================================================
# Regression Mean Absolute Error (MAE): 0.00701
# ==================================================
# Strategy Sharpe Ratio: -0.07  (Benchmark B&H: 0.26)
# ==================================================
# Strategy Sortino Ratio: -0.09
# ==================================================
# Max Peak-to-Trough Drawdown:   -5.60%
# ==================================================
#
#            COMPLETE FEATURE IMPORTANCE RANKINGS
# ==================================================
# Rank 01: RSI                    -> Relative Impact: 21.29%
# Rank 02: price_zscore_50        -> Relative Impact: 10.60%
# Rank 03: Stochastic_14          -> Relative Impact: 8.71%
# Rank 04: volatility_5           -> Relative Impact: 8.11%
# Rank 05: ROC_10                 -> Relative Impact: 7.27%
# Rank 06: returns                -> Relative Impact: 6.90%
# Rank 07: vol_acceleration       -> Relative Impact: 6.25%
# Rank 08: volume_ratio           -> Relative Impact: 5.51%
# Rank 09: HL_spread              -> Relative Impact: 4.75%
# Rank 10: dist_MA_20             -> Relative Impact: 4.67%
# Rank 11: dist_MA_5              -> Relative Impact: 4.53%
# Rank 12: NTR_5                  -> Relative Impact: 3.87%
# Rank 13: volume_spread_ratio    -> Relative Impact: 3.79%
# Rank 14: CO_spread              -> Relative Impact: 3.76%
# ==================================================
#
# ========================================================================================================================================
#                                            WEEKLY MACRO HEALTH CHECK MATRIX
# ========================================================================================================================================
#  [STRUCTURAL TREND]     Close vs 200-Day MA (40-Week Proxy)  : ABOVE (Bullish Structure)
#  [MACRO MOMENTUM]       Close vs 50-Day EMA (10-Week Proxy)  : ABOVE (Macro Momentum Intact)
#  [INSTITUTION VOLUME]   Recent 5-Day Volume Magnitude        : -6.5% Spike vs 20-Day Avg
#  [REGIME VOLATILITY]    5-Day ATR Historical Percentile      : 13.3th Percentile (Historical Scale)
# ========================================================================================================================================
#
# ==================================================================================================================================
#                                    LIVE DAILY DEVELOPMENT SCENARIO MATRIX WITH RISK TARGETS
# ==================================================================================================================================
#  Reference Price Close: 8503.50000  │  Current Daily Volatility Context (ATR_5): 102.16000
#  Last Closed Session:   2026.07.03
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#  STRUCTURAL DEVELOPMENT SCENARIO  │ SIM CLOSE  │ MODEL VECTOR │ TACTICAL VECTOR    │ TAKE PROFIT  │ STOP LOSS
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#  1. Pure Positive Breakout        │ 8564.79600 │ -0.0906%    │ SELL SHORT -0.09x  │ 8411.55600   │ 8666.95600
#  2. Positive + Upper Wick Drop    │ 8513.71600 │ -0.0763%    │ SELL SHORT -0.07x  │ 8360.47600   │ 8615.87600
#  3. Pure Negative Breakdown       │ 8442.20400 │ +0.0468%    │ STANDBY (No Edge)  │   N/A │   N/A
#  4. Negative + Lower Wick Sweep   │ 8493.28400 │ -0.0558%    │ SELL SHORT -0.05x  │ 8340.04400   │ 8595.44400
#  5. Compressed Neutral Chop       │ 8503.50000 │ +0.0488%    │ STANDBY (No Edge)  │   N/A │   N/A
#  6. High-Vol Indecision Cross     │ 8503.50000 │ -0.0333%    │ STANDBY (No Edge)  │   N/A │   N/A
# ==================================================================================================================================
#
#                                           DYNAMIC 4-METRIC DATA-DRIVEN REGIME COCKPIT
# ----------------------------------------------------------------------------------------------------------------------------------
#  [METRIC VALUES]  Trend Z: +2.01 (Med: +0.78) | Mom Dist: +0.0326 (Med: +0.0044)
#                   Vol Spike: -6.5% (Med: -0.5%) | ATR Ratio: 0.84 (Med: 1.00)
# ----------------------------------------------------------------------------------------------------------------------------------
#  [STATE: MATURE INSTITUTIONAL GRIND]
#    -> Profile : Elevated trend and momentum, but trading volume and true range are drying up.
#    -> Bias    : Reduce global position sizes. This is a low-liquidity grinding environment prone to false breakouts.
# ----------------------------------------------------------------------------------------------------------------------------------
#
# Calculating historical macro-durability metrics for engine audit...
#
# =====================================================================
#              DAILY MODEL REGIME RISK & DURABILITY MATRIX
# =====================================================================
#  REGIME ENVIRONMENT               │ STRAT SHARPE │ SORTINO │ MAX DD  │ BENCH SHARPE
# ──────────────────────────────────┼──────────────┼─────────┼─────────┼─────────────
#  Raw Historical Baseline Data     │    -0.07     │  -0.09  │  -5.6% │     0.26
#  Flavor 1: Liquidity Black Hole   │    -0.08     │  -0.10  │  -8.1% │     --
#  Flavor 2: Structural Bear Market │    -0.44     │  -0.50  │ -12.4% │     --
#  Flavor 3: High-Volatility Grind  │     4.25     │   7.17  │  -4.4% │     --
#  Flavor 4: The Gold Rush (Bubble) │    -0.95     │  -0.81  │ -28.6% │     --
# =====================================================================
#
#
# ==================================================
# PROCESSING ASSET PIPELINE FOR: CAT.US-24
# ==================================================
# ==================================================
#            TUNED HISTORICAL BACKTEST RESULTS
# ==================================================
# Regression Mean Absolute Error (MAE): 0.01424
# ==================================================
# Strategy Sharpe Ratio: 0.53  (Benchmark B&H: 1.58)
# ==================================================
# Strategy Sortino Ratio: 0.67
# ==================================================
# Max Peak-to-Trough Drawdown:   -10.57%
# ==================================================
#
#            COMPLETE FEATURE IMPORTANCE RANKINGS
# ==================================================
# Rank 01: volatility_5           -> Relative Impact: 14.04%
# Rank 02: volume_spread_ratio    -> Relative Impact: 9.73%
# Rank 03: NTR_5                  -> Relative Impact: 9.54%
# Rank 04: HL_spread              -> Relative Impact: 9.44%
# Rank 05: returns                -> Relative Impact: 8.70%
# Rank 06: volume_ratio           -> Relative Impact: 8.01%
# Rank 07: vol_acceleration       -> Relative Impact: 7.10%
# Rank 08: dist_MA_5              -> Relative Impact: 7.07%
# Rank 09: price_zscore_50        -> Relative Impact: 6.25%
# Rank 10: dist_MA_20             -> Relative Impact: 4.80%
# Rank 11: CO_spread              -> Relative Impact: 4.46%
# Rank 12: RSI                    -> Relative Impact: 3.84%
# Rank 13: ROC_10                 -> Relative Impact: 3.75%
# Rank 14: Stochastic_14          -> Relative Impact: 3.29%
# ==================================================
#
# ========================================================================================================================================
#                                            WEEKLY MACRO HEALTH CHECK MATRIX
# ========================================================================================================================================
#  [STRUCTURAL TREND]     Close vs 200-Day MA (40-Week Proxy)  : ABOVE (Bullish Structure)
#  [MACRO MOMENTUM]       Close vs 50-Day EMA (10-Week Proxy)  : ABOVE (Macro Momentum Intact)
#  [INSTITUTION VOLUME]   Recent 5-Day Volume Magnitude        : +7.9% Spike vs 20-Day Avg
#  [REGIME VOLATILITY]    5-Day ATR Historical Percentile      : 93.3th Percentile (Historical Scale)
# ========================================================================================================================================
#
# ==================================================================================================================================
#                                    LIVE DAILY DEVELOPMENT SCENARIO MATRIX WITH RISK TARGETS
# ==================================================================================================================================
#  Reference Price Close: 1004.28000  │  Current Daily Volatility Context (ATR_5): 57.63800
#  Last Closed Session:   2026.07.01
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#  STRUCTURAL DEVELOPMENT SCENARIO  │ SIM CLOSE  │ MODEL VECTOR │ TACTICAL VECTOR    │ TAKE PROFIT  │ STOP LOSS
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#  1. Pure Positive Breakout        │ 1038.86280 │ +0.6931%    │ BUY LONG  +0.20x   │ 1125.31980   │ 981.22480
#  2. Positive + Upper Wick Drop    │ 1010.04380 │ +0.5805%    │ BUY LONG  +0.17x   │ 1096.50080   │ 952.40580
#  3. Pure Negative Breakdown       │ 969.69720  │ -0.2081%    │ SELL SHORT -0.06x  │ 883.24020    │ 1027.33520
#  4. Negative + Lower Wick Sweep   │ 998.51620  │ +0.6272%    │ BUY LONG  +0.18x   │ 1084.97320   │ 940.87820
#  5. Compressed Neutral Chop       │ 1004.28000 │ +0.3109%    │ BUY LONG  +0.09x   │ 1090.73700   │ 946.64200
#  6. High-Vol Indecision Cross     │ 1004.28000 │ +0.3315%    │ BUY LONG  +0.10x   │ 1090.73700   │ 946.64200
# ==================================================================================================================================
#
#                                           DYNAMIC 4-METRIC DATA-DRIVEN REGIME COCKPIT
# ----------------------------------------------------------------------------------------------------------------------------------
#  [METRIC VALUES]  Trend Z: +2.01 (Med: +1.43) | Mom Dist: +0.0995 (Med: +0.0365)
#                   Vol Spike: +7.9% (Med: +0.7%) | ATR Ratio: 1.31 (Med: 0.99)
# ----------------------------------------------------------------------------------------------------------------------------------
#  [STATE: INSTITUTIONAL BREAKOUT EXPANSION]
#    -> Profile : Price is structurally bullish, short-term momentum is accelerating, volume and volatility are both spiking.
#    -> Bias    : High momentum exposure environment. Be careful utilizing rigid mean-reversion rules here.
# ----------------------------------------------------------------------------------------------------------------------------------
#
# Calculating historical macro-durability metrics for engine audit...
#
# =====================================================================
#              DAILY MODEL REGIME RISK & DURABILITY MATRIX
# =====================================================================
#  REGIME ENVIRONMENT               │ STRAT SHARPE │ SORTINO │ MAX DD  │ BENCH SHARPE
# ──────────────────────────────────┼──────────────┼─────────┼─────────┼─────────────
#  Raw Historical Baseline Data     │     0.53     │   0.67  │ -10.6% │     1.58
#  Flavor 1: Liquidity Black Hole   │     0.48     │   0.64  │ -11.5% │     --
#  Flavor 2: Structural Bear Market │     1.03     │   1.41  │  -8.4% │     --
#  Flavor 3: High-Volatility Grind  │     3.99     │   6.48  │  -5.6% │     --
#  Flavor 4: The Gold Rush (Bubble) │     0.25     │   0.27  │  -9.6% │     --
# =====================================================================
#
#
# ==================================================
# PROCESSING ASSET PIPELINE FOR: JPM.US-24
# ==================================================
#
# ==================================================
#            TUNED HISTORICAL BACKTEST RESULTS
# ==================================================
# Regression Mean Absolute Error (MAE): 0.01021
# ==================================================
# Strategy Sharpe Ratio: -0.97  (Benchmark B&H: 1.26)
# ==================================================
# Strategy Sortino Ratio: -1.17
# ==================================================
# Max Peak-to-Trough Drawdown:   -14.06%
# ==================================================
#
#            COMPLETE FEATURE IMPORTANCE RANKINGS
# ==================================================
# Rank 01: NTR_5                  -> Relative Impact: 12.38%
# Rank 02: volume_ratio           -> Relative Impact: 9.00%
# Rank 03: volatility_5           -> Relative Impact: 8.91%
# Rank 04: ROC_10                 -> Relative Impact: 8.75%
# Rank 05: HL_spread              -> Relative Impact: 8.70%
# Rank 06: vol_acceleration       -> Relative Impact: 7.78%
# Rank 07: price_zscore_50        -> Relative Impact: 7.43%
# Rank 08: volume_spread_ratio    -> Relative Impact: 7.01%
# Rank 09: RSI                    -> Relative Impact: 6.94%
# Rank 10: dist_MA_20             -> Relative Impact: 5.78%
# Rank 11: Stochastic_14          -> Relative Impact: 5.34%
# Rank 12: CO_spread              -> Relative Impact: 4.39%
# Rank 13: dist_MA_5              -> Relative Impact: 3.87%
# Rank 14: returns                -> Relative Impact: 3.73%
# ==================================================
#
# ========================================================================================================================================
#                                            WEEKLY MACRO HEALTH CHECK MATRIX
# ========================================================================================================================================
#  [STRUCTURAL TREND]     Close vs 200-Day MA (40-Week Proxy)  : ABOVE (Bullish Structure)
#  [MACRO MOMENTUM]       Close vs 50-Day EMA (10-Week Proxy)  : ABOVE (Macro Momentum Intact)
#  [INSTITUTION VOLUME]   Recent 5-Day Volume Magnitude        : -9.7% Spike vs 20-Day Avg
#  [REGIME VOLATILITY]    5-Day ATR Historical Percentile      : 53.3th Percentile (Historical Scale)
# ========================================================================================================================================
#
# ==================================================================================================================================
#                                    LIVE DAILY DEVELOPMENT SCENARIO MATRIX WITH RISK TARGETS
# ==================================================================================================================================
#  Reference Price Close: 333.87000  │  Current Daily Volatility Context (ATR_5): 8.42200
#  Last Closed Session:   2026.07.03
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#  STRUCTURAL DEVELOPMENT SCENARIO  │ SIM CLOSE  │ MODEL VECTOR │ TACTICAL VECTOR    │ TAKE PROFIT  │ STOP LOSS
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#  1. Pure Positive Breakout        │ 338.92320  │ +0.0030%    │ STANDBY (No Edge)  │   N/A │   N/A
#  2. Positive + Upper Wick Drop    │ 334.71220  │ +0.2897%    │ BUY LONG  +0.20x   │ 347.34520    │ 326.29020
#  3. Pure Negative Breakdown       │ 328.81680  │ -0.0926%    │ SELL SHORT -0.06x  │ 316.18380    │ 337.23880
#  4. Negative + Lower Wick Sweep   │ 333.02780  │ +0.2441%    │ BUY LONG  +0.17x   │ 345.66080    │ 324.60580
#  5. Compressed Neutral Chop       │ 333.87000  │ +0.3499%    │ BUY LONG  +0.24x   │ 346.50300    │ 325.44800
#  6. High-Vol Indecision Cross     │ 333.87000  │ +0.2333%    │ BUY LONG  +0.16x   │ 346.50300    │ 325.44800
# ==================================================================================================================================
#
#                                           DYNAMIC 4-METRIC DATA-DRIVEN REGIME COCKPIT
# ----------------------------------------------------------------------------------------------------------------------------------
#  [METRIC VALUES]  Trend Z: +2.28 (Med: +1.36) | Mom Dist: +0.0627 (Med: +0.0235)
#                   Vol Spike: -9.7% (Med: -1.1%) | ATR Ratio: 1.05 (Med: 0.98)
# ----------------------------------------------------------------------------------------------------------------------------------
#  [STATE: TRANSITIONAL REGIME MIX]
#    -> Profile : Mixed macro signals (conflicting trend/momentum directions or detached volume/volatility parameters).
#    -> Bias    : Standard baseline allocations. Let localized technical indicators sort out micro-edge variations.
# ----------------------------------------------------------------------------------------------------------------------------------
#
# Calculating historical macro-durability metrics for engine audit...
#
# =====================================================================
#              DAILY MODEL REGIME RISK & DURABILITY MATRIX
# =====================================================================
#  REGIME ENVIRONMENT               │ STRAT SHARPE │ SORTINO │ MAX DD  │ BENCH SHARPE
# ──────────────────────────────────┼──────────────┼─────────┼─────────┼─────────────
#  Raw Historical Baseline Data     │    -0.97     │  -1.17  │ -14.1% │     1.26
#  Flavor 1: Liquidity Black Hole   │    -0.59     │  -0.72  │ -16.3% │     --
#  Flavor 2: Structural Bear Market │     1.11     │   1.40  │  -6.2% │     --
#  Flavor 3: High-Volatility Grind  │     3.68     │   5.89  │  -4.8% │     --
#  Flavor 4: The Gold Rush (Bubble) │    -0.18     │  -0.29  │  -8.4% │     --
# ...
#  [STRUCTURAL TREND]     Close vs 200-Day MA (40-Week Proxy)  : ABOVE (Bullish Structure)
#  [MACRO MOMENTUM]       Close vs 50-Day EMA (10-Week Proxy)  : ABOVE (Macro Momentum Intact)
#  [INSTITUTION VOLUME]   Recent 5-Day Volume Magnitude        : -9.6% Spike vs 20-Day Avg
#  [REGIME VOLATILITY]    5-Day ATR Historical Percentile      : 53.3th Percentile (Historical Scale)
# ========================================================================================================================================
#
# ==================================================================================================================================
#                                    LIVE DAILY DEVELOPMENT SCENARIO MATRIX WITH RISK TARGETS
# ==================================================================================================================================
#  Reference Price Close: 81.50000  │  Current Daily Volatility Context (ATR_5): 1.77000
#  Last Closed Session:   2026.07.01
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#  STRUCTURAL DEVELOPMENT SCENARIO  │ SIM CLOSE  │ MODEL VECTOR │ TACTICAL VECTOR    │ TAKE PROFIT  │ STOP LOSS
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#  1. Pure Positive Breakout        │ 82.56200   │ -0.3519%    │ SELL SHORT -0.24x  │ 79.90700     │ 84.33200
#  2. Positive + Upper Wick Drop    │ 81.67700   │ -0.2591%    │ SELL SHORT -0.18x  │ 79.02200     │ 83.44700
#  3. Pure Negative Breakdown       │ 80.43800   │ -0.0508%    │ STANDBY (No Edge)  │   N/A │   N/A
#  4. Negative + Lower Wick Sweep   │ 81.32300   │ -0.2395%    │ SELL SHORT -0.17x  │ 78.66800     │ 83.09300
#  5. Compressed Neutral Chop       │ 81.50000   │ -0.2707%    │ SELL SHORT -0.19x  │ 78.84500     │ 83.27000
#  6. High-Vol Indecision Cross     │ 81.50000   │ -0.2315%    │ SELL SHORT -0.16x  │ 78.84500     │ 83.27000
# ==================================================================================================================================
#
#                                           DYNAMIC 4-METRIC DATA-DRIVEN REGIME COCKPIT
# ----------------------------------------------------------------------------------------------------------------------------------
#  [METRIC VALUES]  Trend Z: +1.46 (Med: +0.47) | Mom Dist: +0.0226 (Med: +0.0074)
#                   Vol Spike: -9.6% (Med: +1.6%) | ATR Ratio: 0.95 (Med: 0.98)
# ----------------------------------------------------------------------------------------------------------------------------------
#  [STATE: MATURE INSTITUTIONAL GRIND]
#    -> Profile : Elevated trend and momentum, but trading volume and true range are drying up.
#    -> Bias    : Reduce global position sizes. This is a low-liquidity grinding environment prone to false breakouts.
# ----------------------------------------------------------------------------------------------------------------------------------
#
# Calculating historical macro-durability metrics for engine audit...
#
# =====================================================================
#              DAILY MODEL REGIME RISK & DURABILITY MATRIX
# =====================================================================
#  REGIME ENVIRONMENT               │ STRAT SHARPE │ SORTINO │ MAX DD  │ BENCH SHARPE
# ──────────────────────────────────┼──────────────┼─────────┼─────────┼─────────────
#  Raw Historical Baseline Data     │     0.20     │   0.22  │  -3.6% │     0.52
#  Flavor 1: Liquidity Black Hole   │    -0.44     │  -0.42  │ -10.5% │     --
#  Flavor 2: Structural Bear Market │     0.77     │   1.01  │  -5.4% │     --
#  Flavor 3: High-Volatility Grind  │     2.78     │   4.02  │  -5.7% │     --
#  Flavor 4: The Gold Rush (Bubble) │    -0.47     │  -0.43  │  -7.6% │     --
# =====================================================================
#
#
# ==================================================
# PROCESSING ASSET PIPELINE FOR: DIS.US-24
# ==================================================
#
# ==================================================
#            TUNED HISTORICAL BACKTEST RESULTS
# ==================================================
# Regression Mean Absolute Error (MAE): 0.01180
# ==================================================
# Strategy Sharpe Ratio: -0.50  (Benchmark B&H: -0.04)
# ==================================================
# Strategy Sortino Ratio: -0.58
# ==================================================
# Max Peak-to-Trough Drawdown:   -11.79%
# ==================================================
#
#            COMPLETE FEATURE IMPORTANCE RANKINGS
# ==================================================
# Rank 01: dist_MA_5              -> Relative Impact: 13.05%
# Rank 02: volume_ratio           -> Relative Impact: 10.36%
# Rank 03: dist_MA_20             -> Relative Impact: 10.16%
# Rank 04: volatility_5           -> Relative Impact: 9.88%
# Rank 05: vol_acceleration       -> Relative Impact: 9.10%
# Rank 06: ROC_10                 -> Relative Impact: 9.01%
# Rank 07: volume_spread_ratio    -> Relative Impact: 8.06%
# Rank 08: NTR_5                  -> Relative Impact: 5.78%
# Rank 09: price_zscore_50        -> Relative Impact: 5.44%
# Rank 10: Stochastic_14          -> Relative Impact: 5.26%
# Rank 11: HL_spread              -> Relative Impact: 4.54%
# Rank 12: CO_spread              -> Relative Impact: 3.62%
# Rank 13: RSI                    -> Relative Impact: 3.58%
# Rank 14: returns                -> Relative Impact: 2.16%
# ==================================================
#
# ========================================================================================================================================
#                                            WEEKLY MACRO HEALTH CHECK MATRIX
# ========================================================================================================================================
#  [STRUCTURAL TREND]     Close vs 200-Day MA (40-Week Proxy)  : BELOW (Bearish Structure)
#  [MACRO MOMENTUM]       Close vs 50-Day EMA (10-Week Proxy)  : BELOW (Short-Term Macro Fatigue)
#  [INSTITUTION VOLUME]   Recent 5-Day Volume Magnitude        : -12.5% Spike vs 20-Day Avg
#  [REGIME VOLATILITY]    5-Day ATR Historical Percentile      : 80.0th Percentile (Historical Scale)
# ========================================================================================================================================
#
# ==================================================================================================================================
#                                    LIVE DAILY DEVELOPMENT SCENARIO MATRIX WITH RISK TARGETS
# ==================================================================================================================================
#  Reference Price Close: 98.95000  │  Current Daily Volatility Context (ATR_5): 2.63200
#  Last Closed Session:   2026.07.03
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#  STRUCTURAL DEVELOPMENT SCENARIO  │ SIM CLOSE  │ MODEL VECTOR │ TACTICAL VECTOR    │ TAKE PROFIT  │ STOP LOSS
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#  1. Pure Positive Breakout        │ 100.52920  │ -0.2584%    │ SELL SHORT -0.20x  │ 96.58120     │ 103.16120
#  2. Positive + Upper Wick Drop    │ 99.21320   │ -0.0061%    │ STANDBY (No Edge)  │   N/A │   N/A
#  3. Pure Negative Breakdown       │ 97.37080   │ +0.0309%    │ STANDBY (No Edge)  │   N/A │   N/A
#  4. Negative + Lower Wick Sweep   │ 98.68680   │ +0.0126%    │ STANDBY (No Edge)  │   N/A │   N/A
#  5. Compressed Neutral Chop       │ 98.95000   │ +0.0567%    │ STANDBY (No Edge)  │   N/A │   N/A
#  6. High-Vol Indecision Cross     │ 98.95000   │ +0.1213%    │ BUY LONG  +0.09x   │ 102.89800    │ 96.31800
# ==================================================================================================================================
#
#                                           DYNAMIC 4-METRIC DATA-DRIVEN REGIME COCKPIT
# ----------------------------------------------------------------------------------------------------------------------------------
#  [METRIC VALUES]  Trend Z: -1.31 (Med: -0.13) | Mom Dist: -0.0262 (Med: -0.0098)
#                   Vol Spike: -12.5% (Med: -0.1%) | ATR Ratio: 1.17 (Med: 0.96)
# ----------------------------------------------------------------------------------------------------------------------------------
#  [STATE: TRANSITIONAL REGIME MIX]
#    -> Profile : Mixed macro signals (conflicting trend/momentum directions or detached volume/volatility parameters).
#    -> Bias    : Standard baseline allocations. Let localized technical indicators sort out micro-edge variations.
# ----------------------------------------------------------------------------------------------------------------------------------
#
# Calculating historical macro-durability metrics for engine audit...
#
# =====================================================================
#              DAILY MODEL REGIME RISK & DURABILITY MATRIX
# =====================================================================
#  REGIME ENVIRONMENT               │ STRAT SHARPE │ SORTINO │ MAX DD  │ BENCH SHARPE
# ──────────────────────────────────┼──────────────┼─────────┼─────────┼─────────────
#  Raw Historical Baseline Data     │    -0.50     │  -0.58  │ -11.8% │    -0.04
#  Flavor 1: Liquidity Black Hole   │    -0.41     │  -0.49  │ -13.6% │     --
#  Flavor 2: Structural Bear Market │     0.09     │   0.10  │  -9.6% │     --
#  Flavor 3: High-Volatility Grind  │     3.51     │   6.08  │  -4.3% │     --
#  Flavor 4: The Gold Rush (Bubble) │     0.12     │   0.15  │  -7.7% │     --
# =====================================================================
#
#
# ==================================================
# PROCESSING ASSET PIPELINE FOR: UNH.US-24
# ==================================================
#
# ==================================================
#            TUNED HISTORICAL BACKTEST RESULTS
# ==================================================
# Regression Mean Absolute Error (MAE): 0.01469
# ==================================================
# Strategy Sharpe Ratio: -1.27  (Benchmark B&H: -0.13)
# ==================================================
# Strategy Sortino Ratio: -1.15
# ==================================================
# Max Peak-to-Trough Drawdown:   -32.46%
# ==================================================
#
#            COMPLETE FEATURE IMPORTANCE RANKINGS
# ==================================================
# Rank 01: dist_MA_5              -> Relative Impact: 12.89%
# Rank 02: vol_acceleration       -> Relative Impact: 10.63%
# Rank 03: HL_spread              -> Relative Impact: 10.07%
# Rank 04: CO_spread              -> Relative Impact: 9.72%
# Rank 05: RSI                    -> Relative Impact: 8.27%
# Rank 06: volume_spread_ratio    -> Relative Impact: 6.71%
# Rank 07: NTR_5                  -> Relative Impact: 6.55%
# Rank 08: dist_MA_20             -> Relative Impact: 6.35%
# Rank 09: returns                -> Relative Impact: 6.23%
# Rank 10: price_zscore_50        -> Relative Impact: 5.40%
# Rank 11: volatility_5           -> Relative Impact: 5.03%
# Rank 12: volume_ratio           -> Relative Impact: 5.03%
# Rank 13: ROC_10                 -> Relative Impact: 3.97%
# Rank 14: Stochastic_14          -> Relative Impact: 3.16%
# ==================================================
#
# ========================================================================================================================================
#                                            WEEKLY MACRO HEALTH CHECK MATRIX
# ========================================================================================================================================
#  [STRUCTURAL TREND]     Close vs 200-Day MA (40-Week Proxy)  : ABOVE (Bullish Structure)
#  [MACRO MOMENTUM]       Close vs 50-Day EMA (10-Week Proxy)  : ABOVE (Macro Momentum Intact)
#  [INSTITUTION VOLUME]   Recent 5-Day Volume Magnitude        : -7.4% Spike vs 20-Day Avg
#  [REGIME VOLATILITY]    5-Day ATR Historical Percentile      : 86.7th Percentile (Historical Scale)
# ========================================================================================================================================
#
# ==================================================================================================================================
#                                    LIVE DAILY DEVELOPMENT SCENARIO MATRIX WITH RISK TARGETS
# ==================================================================================================================================
#  Reference Price Close: 425.03000  │  Current Daily Volatility Context (ATR_5): 13.44600
#  Last Closed Session:   2026.07.01
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#  STRUCTURAL DEVELOPMENT SCENARIO  │ SIM CLOSE  │ MODEL VECTOR │ TACTICAL VECTOR    │ TAKE PROFIT  │ STOP LOSS
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#  1. Pure Positive Breakout        │ 433.09760  │ -0.4042%    │ SELL SHORT -0.25x  │ 412.92860    │ 446.54360
#  2. Positive + Upper Wick Drop    │ 426.37460  │ -0.2796%    │ SELL SHORT -0.17x  │ 406.20560    │ 439.82060
#  3. Pure Negative Breakdown       │ 416.96240  │ +0.0693%    │ STANDBY (No Edge)  │   N/A │   N/A
#  4. Negative + Lower Wick Sweep   │ 423.68540  │ +0.0428%    │ STANDBY (No Edge)  │   N/A │   N/A
#  5. Compressed Neutral Chop       │ 425.03000  │ -0.0734%    │ STANDBY (No Edge)  │   N/A │   N/A
#  6. High-Vol Indecision Cross     │ 425.03000  │ +0.3597%    │ BUY LONG  +0.22x   │ 445.19900    │ 411.58400
# ==================================================================================================================================
#
#                                           DYNAMIC 4-METRIC DATA-DRIVEN REGIME COCKPIT
# ----------------------------------------------------------------------------------------------------------------------------------
#  [METRIC VALUES]  Trend Z: +2.17 (Med: -0.38) | Mom Dist: +0.1052 (Med: +0.0007)
#                   Vol Spike: -7.4% (Med: -1.1%) | ATR Ratio: 1.18 (Med: 0.96)
# ----------------------------------------------------------------------------------------------------------------------------------
#  [STATE: TRANSITIONAL REGIME MIX]
#    -> Profile : Mixed macro signals (conflicting trend/momentum directions or detached volume/volatility parameters).
#    -> Bias    : Standard baseline allocations. Let localized technical indicators sort out micro-edge variations.
# ----------------------------------------------------------------------------------------------------------------------------------
#
# Calculating historical macro-durability metrics for engine audit...
#
# =====================================================================
#              DAILY MODEL REGIME RISK & DURABILITY MATRIX
# =====================================================================
#  REGIME ENVIRONMENT               │ STRAT SHARPE │ SORTINO │ MAX DD  │ BENCH SHARPE
# ──────────────────────────────────┼──────────────┼─────────┼─────────┼─────────────
#  Raw Historical Baseline Data     │    -1.27     │  -1.15  │ -32.5% │    -0.13
#  Flavor 1: Liquidity Black Hole   │    -0.75     │  -0.78  │ -29.2% │     --
#  Flavor 2: Structural Bear Market │     0.82     │   1.01  │  -6.5% │     --
#  Flavor 3: High-Volatility Grind  │     3.89     │   7.50  │  -4.1% │     --
#  Flavor 4: The Gold Rush (Bubble) │    -1.31     │  -1.15  │ -30.7% │     --
# =====================================================================

# %%
import pandas as pd 
import project_pkg.trad_econ as te

# https://tradingeconomics.com/matrix

# Define the exact layout schema matching your visible screen columns
COLUMN_NAMES = [
    "Country",
    "GDP",
    "GDP_Growth",
    "Interest_Rate",
    "Inflation_Rate",
    "Unemployment_rate",
    "Gov_Budget",
    "Gov_Debt_to_GDP",
    "Current_Account_to_GDP",
    "Population"  
]

try:
    # 1. Read directly from your computer's clipboard
    df_raw = pd.read_clipboard(header=None, names=COLUMN_NAMES)
    df_raw["Country"] = df_raw["Country"].str.strip()
    df_matrix = df_raw.set_index("Country")
    
    # 2. Force data to numeric so blank fields or strings don't crash the ranks
    for col in df_matrix.columns:
        df_matrix[col] = pd.to_numeric(df_matrix[col], errors='coerce')
    
    # 3. Append the Final Score as the LAST column on the far right
    df_matrix["Final_Macro_Score"] = te.calculate_macro_scores(df_matrix)
    
    # 4. Sort the entire DataFrame by that new column
    df_sorted = df_matrix.sort_values(by="Final_Macro_Score", ascending=False)
    
    print(f"[+] Successfully processed {len(df_sorted)} countries.")
    display(df_sorted)

except Exception as e:
    print(f"[!] Execution Failed. Did you remember to copy the table rows first?")
    print(f"Details: {e}")
# Out:
# [+] Successfully processed 1 countries.
#          GDP  GDP_Growth  Interest_Rate  Inflation_Rate  Unemployment_rate  \
# Country
# i        NaN         NaN            NaN             NaN                NaN
#
#          Gov_Budget  Gov_Debt_to_GDP  Current_Account_to_GDP  Population  \
# Country
# i               NaN              NaN                     NaN         NaN
#
#          Final_Macro_Score
# Country
# i                     0.65

# %%
# # Other shares, softs, hards, etc

# # AU Shares tickers
# au_share_tickers = [
#     "A2M.AU", "ABC.AU", "AGL.AU", "AIA.AU", "AIZ.AU", "ALD.AU", "ALQ.AU", "ALU.AU", "ALX.AU", "AMC.AU",
#     "AMP.AU", "ANN.AU", "ANZ.AU", "APA.AU", "APE.AU", "APX.AU", "ARG.AU", "ARB.AU", "ASB.AU", "ASX.AU",
#     "AST.AU", "AUB.AU", "AWB.AU", "AWL.AU", "AWN.AU", "AWC.AU", "BEN.AU", "BGA.AU", "BHP.AU", "BIN.AU",
#     "BKL.AU", "BKW.AU", "BLD.AU", "BOQ.AU", "BPT.AU", "BRG.AU", "BSL.AU", "BVS.AU", "BWP.AU", "BXB.AU",
#     "CAR.AU", "CBA.AU", "CCP.AU", "CCL.AU", "CGC.AU", "CGF.AU", "CHC.AU", "CIP.AU", "CIM.AU", "CIA.AU",
#     "CLW.AU", "CMW.AU", "CNU.AU", "COL.AU", "COE.AU", "COH.AU", "CPU.AU", "CQR.AU", "CRN.AU", "CSL.AU",
#     "CSR.AU", "CTD.AU", "CUV.AU", "CWN.AU", "CWY.AU", "DHG.AU", "DMP.AU", "DOW.AU", "DDR.AU", "DEG.AU",
#     "DRR.AU", "DXS.AU", "EBO.AU", "EHE.AU", "EHL.AU", "ELD.AU", "EHE.AU", "EML.AU", "EVT.AU", "EVN.AU",
#     "FBU.AU", "FLT.AU", "FMG.AU", "FPH.AU", "GEM.AU", "GNC.AU", "GMG.AU", "GOR.AU", "GOZ.AU", "GPT.AU",
#     "GQG.AU", "GUD.AU", "GWA.AU", "HDN.AU", "HLS.AU", "HMC.AU", "HUB.AU", "HVN.AU", "IAG.AU", "IFT.AU",
#     "IEL.AU", "IFM.AU", "IFL.AU", "ILU.AU", "INA.AU", "INC.AU", "IRE.AU", "IPL.AU", "IPH.AU", "IVC.AU",
#     "JBH.AU", "JHX.AU", "JHG.AU", "JIN.AU", "KGN.AU", "LNK.AU", "LIS.AU", "LLC.AU", "LOV.AU", "LTR.AU",
#     "LYC.AU", "MFG.AU", "MIN.AU", "MGR.AU", "MMS.AU", "MPL.AU", "MP1.AU", "MQG.AU", "MTS.AU", "MYX.AU",
#     "NAN.AU", "NAB.AU", "NEC.AU", "NEU.AU", "NHC.AU", "NHF.AU", "NIC.AU", "NEM.AU", "NCM.AU", "NEA.AU",
#     "NUF.AU", "NSR.AU", "NWH.AU", "NXT.AU", "NWL.AU", "ORA.AU", "ORG.AU", "ORI.AU", "OML.AU", "ORE.AU",
#     "OZL.AU", "PDL.AU", "PDN.AU", "PER.AU", "PLS.AU", "PME.AU", "PMV.AU", "PNI.AU", "PNV.AU", "PPK.AU",
#     "PPT.AU", "PRN.AU", "PRU.AU", "PTM.AU", "PXA.AU", "QAN.AU", "QBE.AU", "QUB.AU", "RBL.AU", "REA.AU",
#     "REH.AU", "REG.AU", "RHC.AU", "RIO.AU", "RMD.AU", "RRL.AU", "RSG.AU", "RWC.AU", "S32.AU", "SAR.AU",
#     "SBM.AU", "SCA.AU", "SCG.AU", "SCP.AU", "SDG.AU", "SDF.AU", "SEK.AU", "SFR.AU", "SGM.AU", "SHL.AU",
#     "SIQ.AU", "SKC.AU", "SKI.AU", "SLC.AU", "SLR.AU", "SML.AU", "SMR.AU", "SOL.AU", "SPK.AU", "SSG.AU",
#     "STO.AU", "SUL.AU", "SUN.AU", "SVW.AU", "SWM.AU", "SYD.AU", "SXL.AU", "TAH.AU", "TCL.AU", "TGR.AU",
#     "TLS.AU", "TLX.AU", "TNE.AU", "TPG.AU", "TWE.AU", "URW.AU", "VCX.AU", "VEA.AU", "VOC.AU", "VNT.AU",
#     "VUK.AU", "WBC.AU", "WEB.AU", "WES.AU", "WMC.AU", "WOR.AU", "WOW.AU", "WPL.AU", "WPR.AU", "WSA.AU",
#     "WTC.AU", "XRO.AU", "YAL.AU", "Z1P.AU"
# ]

# # Combine all tickers and sort
# all_tickers = sorted(au_share_tickers + us_share_tickers + forex_metals_tickers)

# # Create DataFrame and export to CSV
# df = pd.DataFrame(all_tickers, columns
